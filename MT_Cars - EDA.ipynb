# %% [markdown]
# ## MT Cars : Data Analysis
# #### This project use fake MT Cars dataset for Exploratory Data Analysis.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Peek at your data

# %%
df = pd.read_csv("dataset/csv/mtcars.csv")
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.shape
# Out:
# (32, 12)

# %%
df.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %% [markdown]
# ___

# %% [markdown]
# ## 2. Analyzing Individual Feature Patterns using Visualization

# %%
sns.pairplot(df, hue='am')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# In order to start understanding the (linear) relationship between a variable and the mpg, a variable and the hp, a variable and the disp, and a variable and the wt from manual and automatic cars.
#
# #### Positive linear relationship
#
# Let's find the scatterplot of "mpg" and "drat"

# %%
sns.lmplot(x='drat', y='mpg', data=df, hue='am')

# %% [markdown]
# As the drat goes up, the mpg goes up: this indicates a positive direct correlation between these two variables. Drat seems like a pretty good predictor of mpg since the regression line is almost a perfect diagonal line.

# %% [markdown]
# We can examine the correlation between 'mpg' and 'drat'.

# %%
df[['drat','mpg']].corr()
# Out:
#           drat       mpg
# drat  1.000000  0.681172
# mpg   0.681172  1.000000

# %% [markdown]
# Hp is a potential predictor variable of mpg.

# %%
sns.lmplot(x='hp', y='mpg', data=df, hue='am')

# %% [markdown]
# As the hp goes up, the mpg goes down: this indicates an inverse/negative relationship between these two variables. hp could potentially be a predictor of mpg.

# %% [markdown]
# We can examine the correlation between 'hp' and 'mpg'.

# %%
df[['hp','mpg']].corr()
# Out:
#            hp       mpg
# hp   1.000000 -0.776168
# mpg -0.776168  1.000000

# %% [markdown]
# ___

# %% [markdown]
# Disp is a potential predictor variable of hp.

# %%
sns.lmplot(x='disp', y='hp', data=df, hue='am')

# %% [markdown]
# As the disp goes up, the hp goes up: this indicates a positive direct correlation between these two variables. Drat seems like a pretty good predictor of mpg since the regression line is almost a perfect diagonal line.

# %% [markdown]
# We can examine the correlation between 'disp' and 'hp'.

# %%
df[['disp','hp']].corr()
# Out:
#           disp        hp
# disp  1.000000  0.790949
# hp    0.790949  1.000000

# %% [markdown]
# qsec is a potential predictor variable of hp.

# %%
sns.lmplot(x='qsec', y='hp', data=df, hue='am')

# %% [markdown]
# As the qsec goes up, the hp goes down: this indicates an inverse/negative relationship between these two variables. qsec could potentially be a predictor of hp.

# %% [markdown]
# We can examine the correlation between 'qsec' and 'hp'.

# %%
df[['qsec','hp']].corr()
# Out:
#           qsec        hp
# qsec  1.000000 -0.708223
# hp   -0.708223  1.000000

# %% [markdown]
# ___

# %% [markdown]
# wt is a potential predictor variable of disp.

# %%
sns.lmplot(x='wt', y='disp', data=df, hue='am')

# %% [markdown]
# As the wt goes up, the disp goes up: this indicates a positive direct correlation between these two variables. Drat seems like a pretty good predictor of mpg since the regression line is almost a perfect diagonal line.

# %% [markdown]
# We can examine the correlation between 'wt' and 'disp'.

# %%
df[['wt','disp']].corr()
# Out:
#            wt     disp
# wt    1.00000  0.88798
# disp  0.88798  1.00000

# %% [markdown]
# drat is a potential predictor variable of disp.

# %%
sns.lmplot(x='drat', y='disp', data=df, hue='am')

# %% [markdown]
# As the drat goes up, the disp goes down: this indicates an inverse/negative relationship between these two variables. drat could potentially be a predictor of disp.

# %% [markdown]
# We can examine the correlation between 'drat' and 'disp'.

# %%
df[['drat','disp']].corr()
# Out:
#           drat      disp
# drat  1.000000 -0.710214
# disp -0.710214  1.000000

# %% [markdown]
# ___

# %% [markdown]
# ### Categorical Variables

# %%
sns.boxplot(x='am', y='mpg', data=df)

# %% [markdown]
# Here we see that the distribution of mpg between these two transmission categories, automatic (0) and manual (1), are distinct enough to take transmission as a potential good predictor of mpg.

# %%
sns.boxplot(x='am', y='disp', data=df)

# %% [markdown]
# Here we see that the distribution of disp between these two transmission categories, automatic (0) and manual (1), are distinct enough to take transmission as a potential good predictor of disp.

# %%
sns.boxplot(x='am', y='hp', data=df)

# %% [markdown]
# Here we see that the distribution of hp between these two transmission categories, automatic (0) and manual (1), are distinct enough to take transmission as a potential good predictor of hp.

# %% [markdown]
# ___

# %% [markdown]
# ## 3. Descriptive Statistical Analysis

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.groupby('cyl').size()
# Out:
# cyl
# 4    11
# 6     7
# 8    14
# dtype: int64

# %%
df.groupby('vs').size()
# Out:
# vs
# 0    18
# 1    14
# dtype: int64

# %%
df['am'].value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
df['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
df['carb'].value_counts()
# Out:
# 4    10
# 2    10
# 1     7
# 3     3
# 8     1
# 6     1
# Name: carb, dtype: int64

# %%
### Separating for manual (as cars_manu dataframe) and automatic (as cars_auto dataframe) cars.
# Manual Cars
cars_manu = pd.DataFrame()
cars_manu = df[df['am']==1]
cars_manu.head()
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 17       Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18    Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 17     1
# 18     2

# %%
# Automatic Cars
cars_auto = pd.DataFrame()
cars_auto = df[df['am']==0]
cars_auto.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
#
#    carb
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2

# %%
df['mpg'].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %%
cars_manu['mpg'].describe()
# Out:
# count    13.000000
# mean     24.392308
# std       6.166504
# min      15.000000
# 25%      21.000000
# 50%      22.800000
# 75%      30.400000
# max      33.900000
# Name: mpg, dtype: float64

# %%
cars_auto['mpg'].describe()
# Out:
# count    19.000000
# mean     17.147368
# std       3.833966
# min      10.400000
# 25%      14.950000
# 50%      17.300000
# 75%      19.200000
# max      24.400000
# Name: mpg, dtype: float64

# %%
f, axes = plt.subplots(1,2,figsize=(12,4), sharex=True)
sns.distplot(cars_auto['mpg'], kde=False, ax=axes[0]).set(xlabel='mpg', ylabel='Frequency', title='Distribution mpg - Automatic')
sns.distplot(cars_manu['mpg'], kde=False, ax=axes[1]).set(xlabel='mpg', ylabel='Frequency', title='Distribution mpg - Manual')
# Out:
# [Text(0, 0.5, 'Frequency'),
#  Text(0.5, 0, 'mpg'),
#  Text(0.5, 1.0, 'Distribution mpg - Manual')]

# %% [markdown]
# ___

# %% [markdown]
# ## 4. Grouping

# %%
df.head(3)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
cg = df.groupby(by=['cyl','gear']).count()['mpg'].unstack()
cg.head()
# Out:
# gear     3    4    5
# cyl
# 4      1.0  8.0  2.0
# 6      2.0  4.0  1.0
# 8     12.0  NaN  2.0

# %%
cg.fillna(cg[4].notnull().mean())
# Out:
# gear     3         4    5
# cyl
# 4      1.0  8.000000  2.0
# 6      2.0  4.000000  1.0
# 8     12.0  0.666667  2.0

# %%
plt.figure(figsize=[8,4])
sns.heatmap(cg, cmap='viridis')
plt.xlim(0,3)
plt.ylim(0,3)
# Out:
# (0, 3)

# %%
df['hp'].unique()
# Out:
# array([110,  93, 175, 105, 245,  62,  95, 123, 180, 205, 215, 230,  66,
#         52,  65,  97, 150,  91, 113, 264, 335, 109])

# %% [markdown]
# ___

# %% [markdown]
# ## 5. Correlation between attributes

# %%
df.corr(method='pearson')
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df.corr(), cmap='viridis', annot=True, lw=1, linecolor='black')
plt.xlim(0,11)
plt.ylim(11,0)
# Out:
# (11, 0)

# %%
# lakukan t-test menggunakan scipy
from scipy.stats import ttest_ind
t2, p2 = ttest_ind(cars_manu['mpg'], cars_auto['mpg'])
print('t : ', t2)
print('p : ', p2)
# Out:
# t :  4.106126983100689
# p :  0.0002850207439350686

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# <b>P-value</b>:
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(df['mpg'], df['am'])
print("The Pearson Correlation Coefficient (mpg vs am) is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient (mpg vs am) is 0.599832429454648  with a P-value of P = 0.00028502074393506566

# %% [markdown]
# Since the p-value is < 0.001, the correlation between mpg and am is statistically significant, and the linear relationship is strong enough (~0.599) which means that is positive correlation.

# %%
pearson_coef, p_value = stats.pearsonr(df['disp'], df['am'])
print("The Pearson Correlation Coefficient (disp vs am) is", pearson_coef, " with a P-value of P =", p_value)

pearson_coef, p_value = stats.pearsonr(df['disp'], df['gear'])
print("The Pearson Correlation Coefficient (disp vs gear) is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient (disp vs am) is -0.5912270400639477  with a P-value of P = 0.00036621137080554504
# The Pearson Correlation Coefficient (disp vs gear) is -0.5555691985624827  with a P-value of P = 0.0009635920522469475

# %% [markdown]
# Since the p-value is < 0.001, the correlation between disp vs am and disp vs gear is statistically significant, and the linear relationship is strong enough (negative correlations).

# %% [markdown]
# ## 6. Skew of univariate distributions

# %%
df.skew()
# Out:
# mpg     0.672377
# cyl    -0.192261
# disp    0.420233
# hp      0.799407
# drat    0.292780
# wt      0.465916
# qsec    0.406347
# vs      0.264542
# am      0.400809
# gear    0.582309
# carb    1.157091
# dtype: float64

# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %% [markdown]
# ## Data Gathering

# %%
df = pd.read_csv('nations.csv')
df.head()
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  2007         NaN          NaN     82683.0        10.1
# 1    AD   AND  Andorra  2011         NaN          NaN     83751.0         NaN
# 2    AD   AND  Andorra  2013         NaN          NaN     80788.0         NaN
# 3    AD   AND  Andorra  2008         NaN          NaN     83861.0        10.4
# 4    AD   AND  Andorra  1992         NaN          NaN     58888.0        12.1
#
#    neonat_mortal_rate                 region       income
# 0                 1.5  Europe & Central Asia  High income
# 1                 1.3  Europe & Central Asia  High income
# 2                 1.2  Europe & Central Asia  High income
# 3                 1.4  Europe & Central Asia  High income
# 4                 3.6  Europe & Central Asia  High income

# %% [markdown]
# ## Data Understanding

# %%
df.shape
# Out:
# (5697, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5697 entries, 0 to 5696
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   iso2c               5670 non-null   object
#  1   iso3c               5697 non-null   object
#  2   country             5697 non-null   object
#  3   year                5697 non-null   int64
#  4   gdp_percap          4918 non-null   float64
#  5   life_expect         5268 non-null   float64
#  6   population          5681 non-null   float64
#  7   birth_rate          5385 non-null   float64
#  8   neonat_mortal_rate  5130 non-null   float64
#  9   region              5697 non-null   object
#  10  income              5697 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 489.7+ KB

# %%
df['region'].value_counts()
# Out:
# Europe & Central Asia         1512
# Sub-Saharan Africa            1269
# Latin America & Caribbean     1107
# East Asia & Pacific            945
# Middle East & North Africa     567
# South Asia                     216
# North America                   81
# Name: region, dtype: int64

# %%
df['income'].value_counts()
# Out:
# High income            1863
# Lower middle income    1458
# Upper middle income    1431
# Low income              918
# Not classified           27
# Name: income, dtype: int64

# %%
pd.set_option('precision', 3)
df.describe()
# Out:
#           year  gdp_percap  life_expect  population  birth_rate  \
# count  5697.00    4918.000     5268.000   5.681e+03    5385.000
# mean   2003.00   13529.520       68.186   3.001e+07      23.905
# std       7.79   17159.240        9.725   1.205e+08      11.775
# min    1990.00     242.001       27.610   9.003e+03       6.900
# 25%    1996.00    2338.330       62.063   7.457e+05      13.226
# 50%    2003.00    6843.802       70.699   5.379e+06      21.447
# 75%    2010.00   18153.967       75.387   1.799e+07      33.568
# max    2016.00  140037.224       85.417   1.379e+09      55.565
#
#        neonat_mortal_rate
# count            5130.000
# mean               18.919
# std                15.031
# min                 0.600
# 25%                 6.000
# 50%                14.500
# 75%                28.700
# max                75.000

# %%
df.skew()
# Out:
# year                  0.000
# gdp_percap            2.559
# life_expect          -0.813
# population            8.934
# birth_rate            0.532
# neonat_mortal_rate    0.879
# dtype: float64

# %%
df.corr()
# Out:
#                      year  gdp_percap  life_expect  population  birth_rate  \
# year                1.000       0.239        0.240       0.025      -0.201
# gdp_percap          0.239       1.000        0.590      -0.051      -0.534
# life_expect         0.240       0.590        1.000       0.017      -0.869
# population          0.025      -0.051        0.017       1.000      -0.056
# birth_rate         -0.201      -0.534       -0.869      -0.056       1.000
# neonat_mortal_rate -0.242      -0.575       -0.886       0.058       0.847
#
#                     neonat_mortal_rate
# year                            -0.242
# gdp_percap                      -0.575
# life_expect                     -0.886
# population                       0.058
# birth_rate                       0.847
# neonat_mortal_rate               1.000

# %% [markdown]
# ## Data Cleaning

# %%
for i in df.columns:
    a=df[df[i]=='?'].shape[0]
    if a>0:
        print(i, '\t: ', a)
    else:
        print(i, '\t: No Missing Value')
# Out:
# iso2c 	: No Missing Value
# iso3c 	: No Missing Value
# country 	: No Missing Value
# year 	: No Missing Value
# gdp_percap 	: No Missing Value
# life_expect 	: No Missing Value
# population 	: No Missing Value
# birth_rate 	: No Missing Value
# neonat_mortal_rate 	: No Missing Value
# region 	: No Missing Value
# income 	: No Missing Value
# C:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df.isnull().sum()
# Out:
# iso2c                  27
# iso3c                   0
# country                 0
# year                    0
# gdp_percap            779
# life_expect           429
# population             16
# birth_rate            312
# neonat_mortal_rate    567
# region                  0
# income                  0
# dtype: int64

# %%
df['iso2c'].replace(np.NaN, 'UY', inplace=True)

# %%
for i in df.columns:
    a = df[df[i].isnull()].shape[0]
    if a>0:
        df.fillna(df[df[i].notnull()].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# iso2c                 0
# iso3c                 0
# country               0
# year                  0
# gdp_percap            0
# life_expect           0
# population            0
# birth_rate            0
# neonat_mortal_rate    0
# region                0
# income                0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
f, axes = plt.subplots(2,2,figsize=[15,7.5])
sns.distplot(df['gdp_percap'], ax=axes[0,0]).set(xlabel='GDP PerCap', ylabel='Frequency', title='Freq Dist of GDP PerCap')
sns.distplot(df['life_expect'], ax=axes[0,1]).set(xlabel='Life Expect', ylabel='Frequency', title='Freq Dist of Life Exect')
sns.distplot(df['population'], ax=axes[1,0]).set(xlabel='Population', ylabel='Frequency', title='Freq Dist of Population')
sns.distplot(df['birth_rate'], ax=axes[1,1]).set(xlabel='Birth Rate', ylabel='Frequency', title='Freq Dist of Birth Rate')
plt.tight_layout()

# %%
sns.distplot(df['neonat_mortal_rate']).set(xlabel='Neonat Mortal Rate', ylabel='Frequency', title='Freq Dist of Neonat Mortal Rate')
# Out:
# [Text(0, 0.5, 'Frequency'),
#  Text(0.5, 0, 'Neonat Mortal Rate'),
#  Text(0.5, 1.0, 'Freq Dist of Neonat Mortal Rate')]

# %%
sns.pairplot(df, hue='income')

# %% [markdown]
# ### Positive Linear Relationship

# %%
sns.lmplot(x='birth_rate', y='neonat_mortal_rate', data=df, hue='income')

# %%
df[['birth_rate', 'neonat_mortal_rate']].corr(method='pearson')
# Out:
#                     birth_rate  neonat_mortal_rate
# birth_rate               1.000               0.819
# neonat_mortal_rate       0.819               1.000

# %% [markdown]
# ### Negative Linear Relationship

# %%
sns.lmplot(x='birth_rate', y='life_expect', data=df, hue='income')

# %%
df[['birth_rate', 'life_expect']].corr(method='pearson')
# Out:
#              birth_rate  life_expect
# birth_rate         1.00        -0.86
# life_expect       -0.86         1.00

# %%
sns.lmplot(x='neonat_mortal_rate', y='life_expect', data=df, hue='income')

# %%
df[['neonat_mortal_rate', 'life_expect']].corr(method='pearson')
# Out:
#                     neonat_mortal_rate  life_expect
# neonat_mortal_rate               1.000       -0.847
# life_expect                     -0.847        1.000

# %% [markdown]
# ### Categorical Variables

# %%
df.head(3)
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  2007    13529.52       67.993     82683.0      10.100
# 1    AD   AND  Andorra  2011    13529.52       67.993     83751.0      24.134
# 2    AD   AND  Andorra  2013    13529.52       67.993     80788.0      24.134
#
#    neonat_mortal_rate                 region       income
# 0                 1.5  Europe & Central Asia  High income
# 1                 1.3  Europe & Central Asia  High income
# 2                 1.2  Europe & Central Asia  High income

# %%
f, axes = plt.subplots(1,2,figsize=[40,10])
sns.countplot(x='region', data=df, ax=axes[0])
sns.countplot(x='income', data=df, ax=axes[1])

# %%
plt.figure(figsize=[12,6])
sns.boxplot(x='income', y='gdp_percap', data=df)
plt.xticks(fontsize=10)
plt.xlabel('Income', size=15)
plt.ylabel('GDP per Cap', size=15)
# Out:
# Text(0, 0.5, 'GDP per Cap')

# %%
plt.figure(figsize=[12,6])
sns.boxplot(x='region', y='gdp_percap', data=df)
plt.xticks(rotation=-45, fontsize=10)
plt.xlabel('Region', size=15)
plt.ylabel('GDP per Cap', size=15)
# Out:
# Text(0, 0.5, 'GDP per Cap')

# %%
plt.figure(figsize=[25,10])
sns.boxplot(x='region', y='gdp_percap', data=df, hue='income')
plt.xticks(fontsize=14)
plt.xlabel('Income', size=16)
plt.ylabel('GDP per Cap', size=16)
# Out:
# Text(0, 0.5, 'GDP per Cap')

# %%
# high income
df_hi = df[df['income']=='High income']

# Upper middle income
df_umi = df[df['income']=='Upper middle income']

# Lower middle income
df_lmi = df[df['income']=='Lower middle income']

# Low income
df_li = df[df['income']=='Low income']

# Not Classified
df_nc = df[df['income']=='Not classified']

# %%
f, axes = plt.subplots(6,2,figsize=[12,12])
sns.distplot(df_hi['gdp_percap'], ax=axes[0,0]).set(title='GDP PerCap of High Income')
sns.distplot(df_umi['gdp_percap'], ax=axes[0,1]).set(title='GDP PerCap of Upper Middle Income')
sns.distplot(df_lmi['gdp_percap'], ax=axes[1,0]).set(title='GDP PerCap of Low Middle Income')
sns.distplot(df_li['gdp_percap'], ax=axes[1,1]).set(title='GDP PerCap of Low Income')

sns.distplot(df_hi['life_expect'], ax=axes[2,0]).set(title='Life Expect of High Income')
sns.distplot(df_umi['life_expect'], ax=axes[2,1]).set(title='Life Expect of Upper Middle Income')
sns.distplot(df_lmi['life_expect'], ax=axes[3,0]).set(title='Life Expect of Low Middle Income')
sns.distplot(df_li['life_expect'], ax=axes[3,1]).set(title='Life Expect of Low Income')

sns.distplot(df_hi['birth_rate'], ax=axes[4,0]).set(title='Birth Rate of High Income')
sns.distplot(df_umi['birth_rate'], ax=axes[4,1]).set(title='Birth Rate of Upper Middle Income')
sns.distplot(df_lmi['birth_rate'], ax=axes[5,0]).set(title='Birth Rate of Low Middle Income')
sns.distplot(df_li['birth_rate'], ax=axes[5,1]).set(title='Birth Rate of Low Income')

plt.tight_layout()

# %%
df_top5_pop = df.groupby('country').sum().sort_values(['population'], ascending=False).drop('year', axis=1).head()
df_top5_pop
# Out:
#                gdp_percap  life_expect  population  birth_rate  \
# country
# China           1.567e+05     1969.051   3.446e+10     386.030
# India           8.018e+04     1718.511   2.981e+10     674.719
# United States   1.085e+06     2083.893   7.803e+09     379.500
# Indonesia       1.702e+05     1799.772   5.969e+09     590.138
# Brazil          2.944e+05     1915.246   4.882e+09     509.232
#
#                neonat_mortal_rate
# country
# China                       462.2
# India                      1109.6
# United States               123.5
# Indonesia                   566.8
# Brazil                      417.6

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df_top5_pop, cmap='viridis', lw=1, annot=True).set(title='Populations of Top 5 Country in 8 years')
# Out:
# [Text(0.5, 1.0, 'Populations of Top 5 Country in 8 years')]

# %%
sns.clustermap(df_top5_pop, cmap='viridis', standard_scale=1, lw=1, annot=True)

# %%
df_top5_gdp = df.groupby('country').sum().sort_values(['gdp_percap'], ascending=False).drop('year', axis=1).head()
df_top5_gdp
# Out:
#                       gdp_percap  life_expect  population  birth_rate  \
# country
# Qatar                  2.026e+06     2067.328   3.002e+07     440.003
# United Arab Emirates   1.962e+06     2018.214   1.346e+08     427.168
# Brunei Darussalam      1.901e+06     2038.906   9.377e+06     561.855
# Luxembourg             1.753e+06     2124.445   1.250e+07     327.300
# Macao SAR, China       1.700e+06     2184.931   1.261e+07     296.829
#
#                       neonat_mortal_rate
# country
# Qatar                            174.200
# United Arab Emirates             151.500
# Brunei Darussalam                136.200
# Luxembourg                        63.700
# Macao SAR, China                 506.809

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df_top5_gdp, cmap='Blues', lw=1, linecolor='black', annot=True).set(title='GDP perCap of Top 5 Country in 8 years')
# Out:
# [Text(0.5, 1.0, 'GDP perCap of Top 5 Country in 8 years')]

# %%
sns.clustermap(df_top5_gdp, cmap='Blues', standard_scale=1, lw=1, linecolor='black', annot=True)

# %%
df_top5_br = df.groupby('country').sum().sort_values(['birth_rate'], ascending=False).drop('year', axis=1).head()
df_top5_br
# Out:
#          gdp_percap  life_expect  population  birth_rate  neonat_mortal_rate
# country
# Niger     18940.006     1402.461   3.578e+08    1411.094              1064.9
# Chad      35095.832     1317.573   2.603e+08    1320.513              1152.9
# Angola   106814.536     1376.303   5.159e+08    1291.783              1220.5
# Mali      38531.765     1377.198   3.373e+08    1281.735              1412.3
# Uganda    29182.327     1378.995   7.480e+08    1278.425               824.1

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df_top5_br, cmap='Greens', lw=1, linecolor='black', annot=True).set(title='Birth Rate of Top 5 Country in 8 years')
# Out:
# [Text(0.5, 1.0, 'Birth Rate of Top 5 Country in 8 years')]

# %%
sns.clustermap(df_top5_br, cmap='Greens', standard_scale=1, lw=1, linecolor='black', annot=True)

# %%
df_top5_le = df.groupby('country').sum().sort_values(['life_expect'], ascending=False).drop('year', axis=1).head()
df_top5_le
# Out:
#                       gdp_percap  life_expect  population  birth_rate  \
# country
# Japan                  8.073e+05     2200.654   3.421e+09     242.627
# Hong Kong SAR, China   9.504e+05     2193.071   1.799e+08     266.100
# Macao SAR, China       1.700e+06     2184.931   1.261e+07     296.829
# Iceland                9.125e+05     2174.886   7.921e+06     407.600
# Switzerland            1.144e+06     2174.101   2.007e+08     291.200
#
#                       neonat_mortal_rate
# country
# Japan                             43.500
# Hong Kong SAR, China             506.809
# Macao SAR, China                 506.809
# Iceland                           52.400
# Switzerland                       90.000

# %%
plt.figure(figsize=[12,6])
sns.heatmap(df_top5_le, cmap='coolwarm', lw=1, linecolor='black', annot=True).set(title='Life Expect of Top 5 Country in 8 years')
#plt.xlim(0,5)
#plt.ylim(0,5)
# Out:
# [Text(0.5, 1.0, 'Life Expect of Top 5 Country in 8 years')]

# %%
sns.clustermap(df_top5_le, cmap='coolwarm', standard_scale=1, lw=1, linecolor='black', annot=True)

# %% [markdown]
# ### Correlation

# %%
cor = df.corr(method='pearson')
cor
# Out:
#                      year  gdp_percap  life_expect  population  birth_rate  \
# year                1.000       0.219        0.231       0.025      -0.195
# gdp_percap          0.219       1.000        0.547      -0.051      -0.499
# life_expect         0.231       0.547        1.000       0.017      -0.860
# population          0.025      -0.051        0.017       1.000      -0.056
# birth_rate         -0.195      -0.499       -0.860      -0.056       1.000
# neonat_mortal_rate -0.229      -0.512       -0.847       0.058       0.819
#
#                     neonat_mortal_rate
# year                            -0.229
# gdp_percap                      -0.512
# life_expect                     -0.847
# population                       0.058
# birth_rate                       0.819
# neonat_mortal_rate               1.000

# %%
mask = np.zeros_like(cor, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(12,6))
sns.heatmap(cor,
            vmin=-1,
            cmap='coolwarm',
            annot=True,
            mask = mask);

# %% [markdown]
# ## Normalize Data and Feature Extraction

# %%
df['income'] = LabelEncoder().fit(df['income']).transform(df['income'])

# %%
df.head(3)
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  2007    13529.52       67.993     82683.0      10.100
# 1    AD   AND  Andorra  2011    13529.52       67.993     83751.0      24.134
# 2    AD   AND  Andorra  2013    13529.52       67.993     80788.0      24.134
#
#    neonat_mortal_rate                 region  income
# 0                 1.5  Europe & Central Asia       0
# 1                 1.3  Europe & Central Asia       0
# 2                 1.2  Europe & Central Asia       0

# %% [markdown]
# ## p-value

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(df['year'], df['gdp_percap'])
print("The Pearson Correlation Coefficient (year vs gdp_percap) is", pearson_coef, " with a P-value of P =", p_value)

pearson_coef, p_value = stats.pearsonr(df['birth_rate'], df['neonat_mortal_rate'])
print("The Pearson Correlation Coefficient (birth_rate vs neonat_mortal_rate) is", pearson_coef, " with a P-value of P =", p_value)

pearson_coef, p_value = stats.pearsonr(df['birth_rate'], df['life_expect'])
print("The Pearson Correlation Coefficient (birth_rate vs life_expect) is", pearson_coef, " with a P-value of P =", p_value)

pearson_coef, p_value = stats.pearsonr(df['neonat_mortal_rate'], df['life_expect'])
print("The Pearson Correlation Coefficient (neonat_mortal_rate vs life_expect) is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient (year vs gdp_percap) is 0.21943221190173368  with a P-value of P = 4.514191850002976e-63
# The Pearson Correlation Coefficient (birth_rate vs neonat_mortal_rate) is 0.8188981198741979  with a P-value of P = 0.0
# The Pearson Correlation Coefficient (birth_rate vs life_expect) is -0.8595759612932232  with a P-value of P = 0.0
# The Pearson Correlation Coefficient (neonat_mortal_rate vs life_expect) is -0.8472636901076736  with a P-value of P = 0.0

# %% [markdown]
# ___
# ## Data Modeling

# %% [markdown]
# ### Train Test Split

# %%
df.head(3)
# Out:
#   iso2c iso3c  country  year  gdp_percap  life_expect  population  birth_rate  \
# 0    AD   AND  Andorra  2007    13529.52       67.993     82683.0      10.100
# 1    AD   AND  Andorra  2011    13529.52       67.993     83751.0      24.134
# 2    AD   AND  Andorra  2013    13529.52       67.993     80788.0      24.134
#
#    neonat_mortal_rate                 region  income
# 0                 1.5  Europe & Central Asia       0
# 1                 1.3  Europe & Central Asia       0
# 2                 1.2  Europe & Central Asia       0

# %%
X = df.drop(['iso2c', 'iso3c', 'country', 'year', 'region', 'income'], axis=1)
X.head()
# Out:
#    gdp_percap  life_expect  population  birth_rate  neonat_mortal_rate
# 0    13529.52       67.993     82683.0      10.100                 1.5
# 1    13529.52       67.993     83751.0      24.134                 1.3
# 2    13529.52       67.993     80788.0      24.134                 1.2
# 3    13529.52       67.993     83861.0      10.400                 1.4
# 4    13529.52       67.993     58888.0      12.100                 3.6

# %%
y = df['income']
y.head(3)
# Out:
# 0    0
# 1    0
# 2    0
# Name: income, dtype: int32

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
print('Train set: ', X_train.shape, y_train.shape)
print('Test set: ', X_test.shape, y_test.shape)
# Out:
# Train set:  (3987, 5) (3987,)
# Test set:  (1710, 5) (1710,)

# %% [markdown]
# ### Logistic Regression Model

# %%
input_logic = [('scale', StandardScaler()),
               ('logic', LogisticRegression())]

# %%
logic_model = Pipeline(input_logic)
logic_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('logic', LogisticRegression())])

# %%
logic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('logic', LogisticRegression())])

# %%
logic_predict = logic_model.predict(X_test)
logic_predict
# Out:
# array([2, 4, 1, ..., 1, 0, 1])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, logic_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, logic_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, logic_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80       521
#            1       0.69      0.70      0.70       268
#            2       0.64      0.66      0.65       454
#            3       0.60      0.33      0.43         9
#            4       0.61      0.60      0.60       458
#
#     accuracy                           0.69      1710
#    macro avg       0.67      0.62      0.64      1710
# weighted avg       0.69      0.69      0.69      1710
#
#
#
# Train Accuracy:  0.6787057938299473
# Test Accuracy:  0.6912280701754386

# %%
sns.heatmap(
    confusion_matrix(y_test, logic_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# ### Decision Tree Model

# %%
input_dtree = [('scale', StandardScaler()),
               ('dtree', DecisionTreeClassifier(criterion='entropy'))]

# %%
dtree_model = Pipeline(input_dtree)
dtree_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('dtree', DecisionTreeClassifier(criterion='entropy'))])

# %%
dtree_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('dtree', DecisionTreeClassifier(criterion='entropy'))])

# %%
dtree_predict = dtree_model.predict(X_test)
dtree_predict
# Out:
# array([2, 4, 1, ..., 1, 0, 1])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, dtree_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, dtree_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, dtree_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       521
#            1       0.93      0.95      0.94       268
#            2       0.90      0.92      0.91       454
#            3       0.50      0.67      0.57         9
#            4       0.93      0.89      0.91       458
#
#     accuracy                           0.93      1710
#    macro avg       0.84      0.88      0.86      1710
# weighted avg       0.93      0.93      0.93      1710
#
#
#
# Train Accuracy:  1.0
# Test Accuracy:  0.9280701754385965

# %%
sns.heatmap(
    confusion_matrix(y_test, dtree_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# The result from above model is overfitting because accuracy in train data = 1.0 so that mean overfitting. Let's handle overfitting using GridSearchCV.
# ___
#
# #### GridSearch Decision Tree

# %%
input_dtree = [('scale', StandardScaler()),
               ('dtree', DecisionTreeClassifier())]

#hyper parameter tuning
parameters = { 'dtree__criterion' : ['gini', 'entropy'],
               'dtree__splitter' : ['best','random'],
               'dtree__max_depth' : [6,9,12,15,20],
               'dtree__max_leaf_nodes' : [10,18,26,34,42,50]}

# %%
dtree_model = GridSearchCV(Pipeline(input_dtree), parameters, cv=3)
dtree_model
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('dtree', DecisionTreeClassifier())]),
#              param_grid={'dtree__criterion': ['gini', 'entropy'],
#                          'dtree__max_depth': [6, 9, 12, 15, 20],
#                          'dtree__max_leaf_nodes': [10, 18, 26, 34, 42, 50],
#                          'dtree__splitter': ['best', 'random']})

# %%
dtree_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('dtree', DecisionTreeClassifier())]),
#              param_grid={'dtree__criterion': ['gini', 'entropy'],
#                          'dtree__max_depth': [6, 9, 12, 15, 20],
#                          'dtree__max_leaf_nodes': [10, 18, 26, 34, 42, 50],
#                          'dtree__splitter': ['best', 'random']})

# %%
dtree_model.best_score_
# Out:
# 0.8332079257587158

# %%
dtree_model.best_params_
# Out:
# {'dtree__criterion': 'gini',
#  'dtree__max_depth': 20,
#  'dtree__max_leaf_nodes': 50,
#  'dtree__splitter': 'best'}

# %%
dtree_model.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('dtree',
#                  DecisionTreeClassifier(max_depth=20, max_leaf_nodes=50))])

# %%
dtree_predict = dtree_model.predict(X_test)
dtree_predict
# Out:
# array([4, 4, 1, ..., 1, 0, 2])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, dtree_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, dtree_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, dtree_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       521
#            1       0.93      0.95      0.94       268
#            2       0.90      0.92      0.91       454
#            3       0.50      0.67      0.57         9
#            4       0.93      0.89      0.91       458
#
#     accuracy                           0.93      1710
#    macro avg       0.84      0.88      0.86      1710
# weighted avg       0.93      0.93      0.93      1710
#
#
#
# Train Accuracy:  0.873087534487083
# Test Accuracy:  0.9280701754385965

# %%
sns.heatmap(
    confusion_matrix(y_test, dtree_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# ### SVM Model

# %%
input_svm = [('scale', StandardScaler()),
            ('svm', SVC())]

# %%
svm_model = Pipeline(input_svm)
svm_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('svm', SVC())])

# %%
svm_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('svm', SVC())])

# %%
svm_predict = svm_model.predict(X_test)
svm_predict
# Out:
# array([4, 4, 1, ..., 1, 0, 1])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, svm_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, svm_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, svm_predict))
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86       521
#            1       0.74      0.74      0.74       268
#            2       0.71      0.72      0.72       454
#            3       0.00      0.00      0.00         9
#            4       0.74      0.64      0.68       458
#
#     accuracy                           0.76      1710
#    macro avg       0.60      0.60      0.60      1710
# weighted avg       0.75      0.76      0.75      1710
#
#
#
# Train Accuracy:  0.7484324053172812
# Test Accuracy:  0.7573099415204678

# %%
sns.heatmap(
    confusion_matrix(y_test, svm_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# #### GridSearch SVM

# %%
input_svm = [('scale', StandardScaler()),
               ('svm', SVC())]

#hyper parameter tuning
parameters = {'svm__C' : [0.1,1,10,100,1000],
              'svm__kernel' : ['rbf','sigmoid'],
              'svm__gamma' : [1,0.1,0.01,0.001,0.0001]}

# %%
svm_model = GridSearchCV(Pipeline(input_svm), parameters, verbose=3)
svm_model
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('svm', SVC())]),
#              param_grid={'svm__C': [0.1, 1, 10, 100, 1000],
#                          'svm__gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'svm__kernel': ['rbf', 'sigmoid']},
#              verbose=3)

# %%
svm_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=rbf .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=rbf, score=0.739, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=rbf .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=rbf, score=0.738, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=rbf .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=rbf, score=0.752, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=rbf, score=0.726, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=rbf, score=0.745, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, score=0.429, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, score=0.414, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, score=0.353, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, score=0.422, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=0.1, svm__gamma=1, svm__kernel=sigmoid, score=0.407, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, score=0.643, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, score=0.659, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, score=0.676, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, score=0.655, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf, score=0.662, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.619, total=   0.2s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.629, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.641, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.632, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=0.1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.649, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, score=0.617, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, score=0.648, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, score=0.639, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, score=0.631, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf, score=0.631, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.578, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.569, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.585, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.582, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=0.1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.577, total=   0.3s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf, score=0.462, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf, score=0.467, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf, score=0.469, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf, score=0.453, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=rbf, score=0.465, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.342, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.338, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.340, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.343, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=0.1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf, score=0.338, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf, score=0.338, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=rbf, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.336, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.338, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.338, total=   0.4s
# [CV] svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=0.1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.336, total=   0.4s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=rbf .........................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=rbf, score=0.799, total=   0.2s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=rbf .........................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=rbf, score=0.812, total=   0.2s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=rbf .........................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=rbf, score=0.809, total=   0.2s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=rbf .........................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=rbf, score=0.806, total=   0.2s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=rbf .........................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=rbf, score=0.824, total=   0.2s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=sigmoid .....................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=sigmoid, score=0.472, total=   0.3s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=sigmoid .....................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=sigmoid, score=0.431, total=   0.3s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=sigmoid .....................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=sigmoid, score=0.371, total=   0.3s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=sigmoid .....................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=sigmoid, score=0.429, total=   0.3s
# [CV] svm__C=1, svm__gamma=1, svm__kernel=sigmoid .....................
# [CV]  svm__C=1, svm__gamma=1, svm__kernel=sigmoid, score=0.472, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=rbf .......................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=rbf, score=0.695, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=rbf .......................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=rbf, score=0.704, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=rbf .......................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=rbf, score=0.708, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=rbf .......................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=rbf, score=0.679, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=rbf .......................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=rbf, score=0.701, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid ...................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.634, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid ...................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.617, total=   0.1s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid ...................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.668, total=   0.1s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid ...................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.640, total=   0.1s
# [CV] svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid ...................
# [CV]  svm__C=1, svm__gamma=0.1, svm__kernel=sigmoid, score=0.627, total=   0.1s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=rbf ......................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=rbf, score=0.657, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=rbf ......................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=rbf, score=0.665, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=rbf ......................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=rbf, score=0.680, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=rbf ......................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=rbf, score=0.657, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=rbf ......................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=rbf, score=0.670, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid ..................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.640, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid ..................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.653, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid ..................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.670, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid ..................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.650, total=   0.2s
# [CV] svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid ..................
# [CV]  svm__C=1, svm__gamma=0.01, svm__kernel=sigmoid, score=0.661, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=rbf .....................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=rbf, score=0.615, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=rbf .....................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=rbf, score=0.645, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=rbf .....................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=rbf, score=0.641, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=rbf .....................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=rbf, score=0.627, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=rbf .....................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=rbf, score=0.630, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid .................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.579, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid .................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.568, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid .................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.583, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid .................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.582, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid .................
# [CV]  svm__C=1, svm__gamma=0.001, svm__kernel=sigmoid, score=0.580, total=   0.3s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=rbf ....................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=rbf, score=0.464, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=rbf ....................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=rbf, score=0.470, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=rbf ....................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=rbf, score=0.472, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=rbf ....................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=rbf, score=0.455, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=rbf ....................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=rbf, score=0.468, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid ................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.342, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid ................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.338, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid ................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.340, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid ................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.343, total=   0.4s
# [CV] svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid ................
# [CV]  svm__C=1, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.336, total=   0.4s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=rbf ........................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=rbf, score=0.868, total=   0.2s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=rbf ........................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=rbf, score=0.865, total=   0.2s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=rbf ........................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=rbf, score=0.859, total=   0.2s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=rbf ........................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=rbf, score=0.848, total=   0.2s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=rbf ........................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=rbf, score=0.876, total=   0.2s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=sigmoid ....................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=sigmoid, score=0.416, total=   0.3s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=sigmoid ....................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=sigmoid, score=0.431, total=   0.3s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=sigmoid ....................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=sigmoid, score=0.430, total=   0.3s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=sigmoid ....................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=sigmoid, score=0.424, total=   0.3s
# [CV] svm__C=10, svm__gamma=1, svm__kernel=sigmoid ....................
# [CV]  svm__C=10, svm__gamma=1, svm__kernel=sigmoid, score=0.425, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=rbf ......................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=rbf, score=0.763, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=rbf ......................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=rbf, score=0.752, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=rbf ......................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=rbf, score=0.775, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=rbf ......................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=rbf, score=0.738, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=rbf ......................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=rbf, score=0.773, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid ..................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid, score=0.642, total=   0.1s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid ..................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid, score=0.625, total=   0.1s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid ..................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid, score=0.664, total=   0.1s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid ..................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid, score=0.636, total=   0.1s
# [CV] svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid ..................
# [CV]  svm__C=10, svm__gamma=0.1, svm__kernel=sigmoid, score=0.631, total=   0.1s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=rbf .....................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=rbf, score=0.683, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=rbf .....................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=rbf, score=0.677, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=rbf .....................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=rbf, score=0.685, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=rbf .....................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=rbf, score=0.662, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=rbf .....................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=rbf, score=0.695, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid .................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid, score=0.653, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid .................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid, score=0.644, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid .................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid, score=0.686, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid .................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid, score=0.651, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid .................
# [CV]  svm__C=10, svm__gamma=0.01, svm__kernel=sigmoid, score=0.686, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=rbf ....................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=rbf, score=0.658, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=rbf ....................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=rbf, score=0.664, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=rbf ....................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=rbf, score=0.679, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=rbf ....................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=rbf, score=0.660, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=rbf ....................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=rbf, score=0.671, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid ................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid, score=0.640, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid ................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid, score=0.654, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid ................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid, score=0.670, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid ................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid, score=0.650, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid ................
# [CV]  svm__C=10, svm__gamma=0.001, svm__kernel=sigmoid, score=0.661, total=   0.2s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=rbf ...................
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=rbf, score=0.614, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=rbf ...................
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=rbf, score=0.644, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=rbf ...................
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=rbf, score=0.641, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=rbf ...................
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=rbf, score=0.625, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=rbf ...................
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=rbf, score=0.630, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid ...............
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.579, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid ...............
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.568, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid ...............
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.583, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid ...............
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.582, total=   0.3s
# [CV] svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid ...............
# [CV]  svm__C=10, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.580, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=rbf, score=0.916, total=   0.2s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=rbf, score=0.902, total=   0.2s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=rbf, score=0.903, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=rbf, score=0.883, total=   0.2s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=rbf .......................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=rbf, score=0.908, total=   0.2s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=sigmoid, score=0.417, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=sigmoid, score=0.430, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=sigmoid, score=0.476, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=sigmoid, score=0.422, total=   0.3s
# [CV] svm__C=100, svm__gamma=1, svm__kernel=sigmoid ...................
# [CV]  svm__C=100, svm__gamma=1, svm__kernel=sigmoid, score=0.425, total=   0.3s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=rbf, score=0.796, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=rbf, score=0.794, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=rbf, score=0.812, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=rbf, score=0.790, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=rbf .....................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=rbf, score=0.814, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, score=0.624, total=   0.1s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, score=0.618, total=   0.1s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, score=0.661, total=   0.1s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, score=0.634, total=   0.1s
# [CV] svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid .................
# [CV]  svm__C=100, svm__gamma=0.1, svm__kernel=sigmoid, score=0.632, total=   0.1s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=rbf, score=0.699, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=rbf, score=0.718, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=rbf, score=0.711, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=rbf, score=0.680, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=rbf ....................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=rbf, score=0.709, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, score=0.635, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, score=0.623, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, score=0.659, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, score=0.671, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid ................
# [CV]  svm__C=100, svm__gamma=0.01, svm__kernel=sigmoid, score=0.641, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=rbf, score=0.677, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=rbf, score=0.688, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=rbf, score=0.688, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=rbf, score=0.654, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=rbf ...................
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=rbf, score=0.690, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid, score=0.668, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid, score=0.664, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid, score=0.689, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid, score=0.660, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid ...............
# [CV]  svm__C=100, svm__gamma=0.001, svm__kernel=sigmoid, score=0.688, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=rbf, score=0.658, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=rbf, score=0.663, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=rbf, score=0.679, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=rbf, score=0.664, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=rbf ..................
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=rbf, score=0.670, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.640, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.654, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.670, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.650, total=   0.2s
# [CV] svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid ..............
# [CV]  svm__C=100, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.661, total=   0.2s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=rbf ......................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=rbf, score=0.946, total=   0.6s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=rbf ......................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=rbf, score=0.921, total=   0.5s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=rbf ......................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=rbf, score=0.928, total=   0.6s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=rbf ......................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=rbf, score=0.921, total=   0.5s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=rbf ......................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=rbf, score=0.936, total=   0.5s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=sigmoid ..................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=sigmoid, score=0.417, total=   0.3s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=sigmoid ..................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=sigmoid, score=0.430, total=   0.3s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=sigmoid ..................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=sigmoid, score=0.472, total=   0.3s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=sigmoid ..................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=sigmoid, score=0.422, total=   0.3s
# [CV] svm__C=1000, svm__gamma=1, svm__kernel=sigmoid ..................
# [CV]  svm__C=1000, svm__gamma=1, svm__kernel=sigmoid, score=0.425, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=rbf ....................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=rbf, score=0.840, total=   0.5s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=rbf ....................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=rbf, score=0.840, total=   0.5s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=rbf ....................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=rbf, score=0.842, total=   0.5s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=rbf ....................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=rbf, score=0.826, total=   0.5s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=rbf ....................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=rbf, score=0.854, total=   0.5s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid ................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid, score=0.620, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid ................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid, score=0.617, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid ................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid, score=0.657, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid ................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid, score=0.631, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid ................
# [CV]  svm__C=1000, svm__gamma=0.1, svm__kernel=sigmoid, score=0.622, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=rbf ...................
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=rbf, score=0.761, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=rbf ...................
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=rbf, score=0.752, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=rbf ...................
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=rbf, score=0.769, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=rbf ...................
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=rbf, score=0.745, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=rbf ...................
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=rbf, score=0.748, total=   0.3s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid ...............
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid, score=0.623, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid ...............
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid, score=0.600, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid ...............
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid, score=0.629, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid ...............
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid, score=0.635, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid ...............
# [CV]  svm__C=1000, svm__gamma=0.01, svm__kernel=sigmoid, score=0.617, total=   0.1s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=rbf ..................
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=rbf, score=0.692, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=rbf ..................
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=rbf, score=0.698, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=rbf ..................
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=rbf, score=0.690, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=rbf ..................
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=rbf, score=0.661, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=rbf ..................
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=rbf, score=0.714, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid ..............
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid, score=0.678, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid ..............
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid, score=0.692, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid ..............
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid, score=0.700, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid ..............
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid, score=0.650, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid ..............
# [CV]  svm__C=1000, svm__gamma=0.001, svm__kernel=sigmoid, score=0.708, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf .................
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf, score=0.674, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf .................
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf, score=0.689, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf .................
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf, score=0.689, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf .................
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf, score=0.656, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf .................
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=rbf, score=0.681, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid .............
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.667, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid .............
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.663, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid .............
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.689, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid .............
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.660, total=   0.2s
# [CV] svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid .............
# [CV]  svm__C=1000, svm__gamma=0.0001, svm__kernel=sigmoid, score=0.689, total=   0.2s
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:  1.1min finished
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('svm', SVC())]),
#              param_grid={'svm__C': [0.1, 1, 10, 100, 1000],
#                          'svm__gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'svm__kernel': ['rbf', 'sigmoid']},
#              verbose=3)

# %%
svm_model.best_score_
# Out:
# 0.9305226680251444

# %%
svm_model.best_params_
# Out:
# {'svm__C': 1000, 'svm__gamma': 1, 'svm__kernel': 'rbf'}

# %%
svm_model.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('svm', SVC(C=1000, gamma=1))])

# %%
svm_predict = svm_model.predict(X_test)
svm_predict
# Out:
# array([2, 4, 1, ..., 1, 0, 2])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, svm_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, svm_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, svm_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       521
#            1       0.95      0.99      0.97       268
#            2       0.97      0.95      0.96       454
#            3       0.82      1.00      0.90         9
#            4       0.94      0.89      0.91       458
#
#     accuracy                           0.94      1710
#    macro avg       0.92      0.96      0.94      1710
# weighted avg       0.94      0.94      0.94      1710
#
#
#
# Train Accuracy:  0.9661399548532731
# Test Accuracy:  0.9444444444444444

# %%
sns.heatmap(
    confusion_matrix(y_test, svm_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# ### Random Forest Model

# %%
input_rf = [('scale', StandardScaler()),
           ('rf', RandomForestClassifier())]

# %%
rf_model = Pipeline(input_rf)
rf_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('rf', RandomForestClassifier())])

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('rf', RandomForestClassifier())])

# %%
rf_predict = rf_model.predict(X_test)
rf_predict
# Out:
# array([2, 4, 1, ..., 1, 0, 2])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, rf_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, rf_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, rf_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       521
#            1       0.96      0.99      0.97       268
#            2       0.95      0.96      0.96       454
#            3       1.00      0.78      0.88         9
#            4       0.96      0.93      0.95       458
#
#     accuracy                           0.96      1710
#    macro avg       0.97      0.93      0.95      1710
# weighted avg       0.96      0.96      0.96      1710
#
#
#
# Train Accuracy:  1.0
# Test Accuracy:  0.9614035087719298

# %%
sns.heatmap(
    confusion_matrix(y_test, rf_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# ___
# #### GridSearch Random Forest

# %%
input_rf = [('scale', StandardScaler()),
               ('rf', RandomForestClassifier())]

#hyper parameter tuning
parameters = {'rf__criterion' : ['gini', 'entropy'],
              'rf__max_features' : ['auto','sqrt','log2'],
              'rf__max_depth' : [3,6,9],
              'rf__max_leaf_nodes' : [9,12],
              'rf__verbose' : [3,6]}

# %%
rf_model = GridSearchCV(Pipeline(input_rf), parameters, cv=3)
rf_model
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('rf', RandomForestClassifier())]),
#              param_grid={'rf__criterion': ['gini', 'entropy'],
#                          'rf__max_depth': [3, 6, 9],
#                          'rf__max_features': ['auto', 'sqrt', 'log2'],
#                          'rf__max_leaf_nodes': [9, 12], 'rf__verbose': [3, 6]})

# %%
rf_model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# ...
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.2s finished
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('rf', RandomForestClassifier())]),
#              param_grid={'rf__criterion': ['gini', 'entropy'],
#                          'rf__max_depth': [3, 6, 9],
#                          'rf__max_features': ['auto', 'sqrt', 'log2'],
#                          'rf__max_leaf_nodes': [9, 12], 'rf__verbose': [3, 6]})

# %%
rf_model.best_score_
# Out:
# 0.7898169049410585

# %%
rf_model.best_params_
# Out:
# {'rf__criterion': 'gini',
#  'rf__max_depth': 9,
#  'rf__max_features': 'log2',
#  'rf__max_leaf_nodes': 12,
#  'rf__verbose': 6}

# %%
rf_model.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('rf',
#                  RandomForestClassifier(max_depth=9, max_features='log2',
#                                         max_leaf_nodes=12, verbose=6))])

# %%
rf_predict = rf_model.predict(X_test)
rf_predict
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# array([4, 4, 1, ..., 1, 0, 2])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, rf_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, rf_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, rf_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87       521
#            1       0.80      0.81      0.81       268
#            2       0.72      0.74      0.73       454
#            3       0.00      0.00      0.00         9
#            4       0.72      0.60      0.65       458
#
#     accuracy                           0.77      1710
#    macro avg       0.61      0.62      0.61      1710
# weighted avg       0.76      0.77      0.76      1710
#
#
#
# Train Accuracy:  0.7880611988964134
# Test Accuracy:  0.7660818713450293
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
sns.heatmap(
    confusion_matrix(y_test, rf_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# ### K-Nearest Neighbors Model

# %%
input_knn = [('scale', StandardScaler()),
             ('knn', KNeighborsClassifier())]

# %%
knn_model = Pipeline(input_knn)
knn_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsClassifier())])

# %%
knn_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsClassifier())])

# %%
knn_predict = knn_model.predict(X_test)
knn_predict
# Out:
# array([2, 0, 1, ..., 1, 0, 1])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, knn_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, knn_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, knn_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       521
#            1       0.86      0.94      0.90       268
#            2       0.91      0.90      0.91       454
#            3       0.86      0.67      0.75         9
#            4       0.93      0.88      0.90       458
#
#     accuracy                           0.91      1710
#    macro avg       0.90      0.87      0.88      1710
# weighted avg       0.92      0.91      0.91      1710
#
#
#
# Train Accuracy:  0.9581138700777527
# Test Accuracy:  0.9146198830409357

# %%
sns.heatmap(
    confusion_matrix(y_test, knn_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()

# %% [markdown]
# #### Choosing a K value

# %%
error_rate = []

for i in range(1,50):
    knn = KNeighborsClassifier(n_neighbors=i).fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,50),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
Ks = 51
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.53567251, 0.51461988, 0.52865497, 0.52105263, 0.50935673,
#        0.50701754, 0.50760234, 0.51637427, 0.50818713, 0.5128655 ,
#        0.51169591, 0.50526316, 0.50760234, 0.51052632, 0.4994152 ,
#        0.49766082, 0.49473684, 0.50175439, 0.49649123, 0.50116959,
#        0.49707602, 0.48479532, 0.49298246, 0.49473684, 0.50175439,
#        0.49473684, 0.49649123, 0.50292398, 0.50175439, 0.49824561,
#        0.50116959, 0.49181287, 0.49356725, 0.48654971, 0.49239766,
#        0.50116959, 0.49298246, 0.49181287, 0.49239766, 0.49005848,
#        0.48538012, 0.48011696, 0.4754386 , 0.46900585, 0.47719298,
#        0.47192982, 0.47660819, 0.4748538 , 0.47777778, 0.46900585])

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Chose n_neighbors = 3

# %%
input_knn = [('scale', StandardScaler()),
             ('knn', KNeighborsClassifier(n_neighbors=3))]

# %%
knn_model = Pipeline(input_knn)
knn_model
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('knn', KNeighborsClassifier(n_neighbors=3))])

# %%
knn_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('knn', KNeighborsClassifier(n_neighbors=3))])

# %%
knn_predict = knn_model.predict(X_test)
knn_predict
# Out:
# array([2, 4, 1, ..., 1, 0, 2])

# %% [markdown]
# #### Evaluation

# %%
print('Classification Report: \n', classification_report(y_test, knn_predict))
print('\n')
print('Train Accuracy: ', metrics.accuracy_score(y_train, knn_model.predict(X_train)))
print('Test Accuracy: ', metrics.accuracy_score(y_test, knn_predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       521
#            1       0.91      0.96      0.93       268
#            2       0.94      0.94      0.94       454
#            3       0.78      0.78      0.78         9
#            4       0.95      0.91      0.93       458
#
#     accuracy                           0.94      1710
#    macro avg       0.91      0.91      0.91      1710
# weighted avg       0.94      0.94      0.94      1710
#
#
#
# Train Accuracy:  0.981439678956609
# Test Accuracy:  0.9403508771929825

# %%
sns.heatmap(
    confusion_matrix(y_test, knn_predict),
    annot=True, cmap = 'Pastel2_r', fmt='.0f'
)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Predicted', fontsize=15)
plt.ylabel('Actual', fontsize=15)
plt.show()
